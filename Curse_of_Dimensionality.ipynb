# %%
import numpy as np
from math import dist
from matplotlib import pyplot as plt
from scipy.spatial.distance import cdist

# %% [markdown]
# Implementation of 1000 random n dimensional data points, and finding the distance between each pair of them. The **histogram** of the distances is shown below:
#
#
# dim = 5:

# %%
numbers=[]
for i in range (1000):
    numbers.append(np.random.rand(5))
distance = cdist(numbers, numbers, metric = 'euclidean')
distance = np.array(distance[distance!=0])
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(distance, bins = 100)
plt.title("n = 1000, d = 5")
plt.show()

# %% [markdown]
# dim = 2000:

# %%
numbers=[]
for i in range (1000):
    numbers.append(np.random.rand(2000))
distance = cdist(numbers, numbers, metric = 'euclidean')
distance = np.array(distance[distance!=0])
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(distance, bins = 100)
plt.title("n = 1000, d = 2000")
plt.show()

# %% [markdown]
# dim = 5000:

# %%
numbers=[]
for i in range (1000):
    numbers.append(np.random.rand(5000))
distance = cdist(numbers, numbers, metric = 'euclidean')
distance = np.array(distance[distance!=0])
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(distance, bins = 100)
plt.title("n = 1000, d = 5000")
plt.show()

# %% [markdown]
# dim = 10000:

# %%
numbers=[]
for i in range (1000):
    numbers.append(np.random.rand(10000))
distance = cdist(numbers, numbers, metric = 'euclidean')
distance = np.array(distance[distance!=0])
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(distance, bins = 100)
plt.title("n = 1000, d = 10000")
plt.show()

# %% [markdown]
# Now I fix the dimension to 10000, and check different values for the length of the vector:
#
#
# length of vector = 2000:

# %%
numbers=[]
for i in range (2000):
    numbers.append(np.random.rand(10000))
distance = cdist(numbers, numbers, metric = 'euclidean')
distance = np.array(distance[distance!=0])
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(distance, bins = 100)
plt.title("n = 2000, d = 10000")
plt.show()

# %% [markdown]
# length of vector = 5000:

# %%
numbers=[]
for i in range (5000):
    numbers.append(np.random.rand(10000))
distance = cdist(numbers, numbers, metric = 'euclidean')
distance = np.array(distance[distance!=0])
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(distance, bins = 100)
plt.title("n = 5000, d = 10000")
plt.show()

# %% [markdown]
# In **KNN** method, we fix the size of k, and increase the size window until we have k samples inside it. As it can be seen in the above implementations, by increasing the number of samples in large dimensions, the computations become very **complex** and take a **long time**. So, in these kinds of datasets, it's better to **fix the number of samples** and **increase the size of the window**, because the computations are going to be a lot **faster**.
#
#
# The relation between this project and the curse of dimensionality, is the **huge amount of computations** that occur when **increasing the dimensions** in the problem. In fact, the number of the samples need to be increased so that the **density** of data stays the same.
